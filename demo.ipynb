# %%
# !pip install --index-url https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ hello-world-Przemek-Bukala
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# ...

# %%
from fuel_estimator import estimate_trip_fuel, si

distance = 150 * si.kilometer
base_consumption = 6.5 * (si.liter / (100 * si.kilometer))

estimated_fuel = estimate_trip_fuel(distance, base_consumption)

print(f"Distance: {distance}")
print(f"Base_consumption: {base_consumption}")
print(f"Estimated fuel usage: {estimated_fuel:.2f}")
# Out:
# Distance: 150 kilometer
# Base_consumption: 0.065 liter / kilometer
# Estimated fuel usage: 11.13 liter
